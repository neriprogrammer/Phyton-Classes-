# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC','^IXIC', '^GDAXI', '^BVSP'] 

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI          ^BVSP
# Date
# 1997-01-02   737.010010   1280.699951   2820.810059    6955.500000
# 1997-01-03   748.030029   1310.680054   2863.260010    6997.799805
# 1997-01-06   747.650024   1316.400024   2890.199951    7159.500000
# 1997-01-07   753.229980   1327.729980   2876.340088    7159.500000
# 1997-01-08   748.409973   1320.349976   2904.080078    7427.000000
# ...                 ...           ...           ...            ...
# 2022-02-07  4483.870117  14015.669922  15206.639648  111996.000000
# 2022-02-08  4521.540039  14194.450195  15242.379883  112234.000000
# 2022-02-09  4587.180176  14490.370117  15482.009766  112461.000000
# 2022-02-10  4504.080078  14185.639648  15490.440430  113359.000000
# 2022-02-11  4418.640137  13791.150391  15425.120117  113495.000000
#
# [6322 rows x 4 columns]

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI     ^BVSP
# Date
# 2022-02-07  4483.870117  14015.669922  15206.639648  111996.0
# 2022-02-08  4521.540039  14194.450195  15242.379883  112234.0
# 2022-02-09  4587.180176  14490.370117  15482.009766  112461.0
# 2022-02-10  4504.080078  14185.639648  15490.440430  113359.0
# 2022-02-11  4418.640137  13791.150391  15425.120117  113495.0

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15,6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^BVSP
# Date
# 2022-02-07 -0.003702 -0.005841  0.007092 -0.002973
# 2022-02-08  0.008401  0.012756  0.002350  0.002125
# 2022-02-09  0.014517  0.020848  0.015721  0.002023
# 2022-02-10 -0.018116 -0.021030  0.000545  0.007985
# 2022-02-11 -0.018969 -0.027809 -0.004217  0.001200

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.089831
# ^IXIC     0.125208
# ^GDAXI    0.079606
# ^BVSP     0.146392
# dtype: float64

# %%
tickers = ['PG', '^GDAXI', '^DJI'] 

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
data_2
# Out:
#                     PG        ^GDAXI          ^DJI
# Date
# 1997-01-02   14.193212   2820.810059   6442.490234
# 1997-01-03   14.426167   2863.260010   6544.089844
# 1997-01-06   14.526001   2890.199951   6567.180176
# 1997-01-07   14.792222   2876.340088   6600.660156
# 1997-01-08   14.526001   2904.080078   6549.479980
# ...                ...           ...           ...
# 2022-02-07  160.320007  15206.639648  35091.128906
# 2022-02-08  159.960007  15242.379883  35462.781250
# 2022-02-09  159.600006  15482.009766  35768.058594
# 2022-02-10  157.169998  15490.440430  35241.589844
# 2022-02-11  156.289993  15425.120117  34738.058594
#
# [6322 rows x 3 columns]

# %%
data_2.tail()
# Out:
#                     PG        ^GDAXI          ^DJI
# Date
# 2022-02-07  160.320007  15206.639648  35091.128906
# 2022-02-08  159.960007  15242.379883  35462.781250
# 2022-02-09  159.600006  15482.009766  35768.058594
# 2022-02-10  157.169998  15490.440430  35241.589844
# 2022-02-11  156.289993  15425.120117  34738.058594

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15,6));
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
